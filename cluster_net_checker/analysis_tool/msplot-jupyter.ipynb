# %% [markdown]
# rows：行
# columns：列
# metric：观察指标
# is_all：是否展示所有节点
# rank_id：要查看的rank拓扑关系
# top_num：直方排序图中查看前几个

# %%
import msplot
from preprocess import data_preparation
input_path = ""
output_path = ""

rows = 4
columns = 4
metric = "computing"
is_all = True
rank_id = 6
top_num = 10
relation = "pp_group_ranks"

data_preparation(input_path, output_path)
msplot.data_parse(rows, columns, output_path)
msplot.run_topo(metric, rank_id, is_all)
msplot.run_histogram(metric, relation, rank_id, is_all, top_num)
